# %% [markdown]
# #
#
# These examples are based on **Chapter X** of *Econometrics* by

# %%
from linearmodels.datasets import ak1991

# %%
ak1991.load()
# Out:
#         Unnamed: 0   ageq  edu   logwage  married  state  qob  black  smsa  \
# 0                0  47.00   12  6.245846        1      1    1      1     1
# 1                1  46.25   12  5.847161        1     48    4      1     1
# 2                2  50.00   12  6.645516        1      2    1      1     1
# 3                3  47.00   16  6.706133        1     22    1      1     1
# 4                4  42.25   14  6.357876        1     42    4      1     1
# 5                5  44.25   12  5.441835        1      5    4      1     1
# 6                6  42.00   12  6.390660        1     42    1      1     1
# 7                7  50.00   12  4.607667        1     48    1      1     1
# 8                8  40.50   12  6.553961        1      5    3      1     1
# 9                9  43.75    7  7.017041        0      2    2      1     1
# 10              10  45.50   14  6.390660        0     47    3      1     1
# ...
